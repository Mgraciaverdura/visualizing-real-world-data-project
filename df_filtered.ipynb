# %% [markdown]
# # Filtrado de base de datos companies.json

# %% [markdown]
# Importo las librerías.

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
db = client["companies"]

from pandas.io.json import json_normalize

import pandas as pd

data = db.companies.find()

# %%
dataset = pd.DataFrame(list(data))
dataset.head()
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d92
# 2  52cdef7c4bab8bd675297d8c
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d93
#
#                                          acquisition  \
# 0                                               None
# 1  {u'acquired_month': 5, u'price_amount': 200000...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []                None
# 2                                                 []
# 3                                                 []                None
# 4  [{u'acquired_month': 5, u'price_amount': 20000...                None
#
# ...

# %%
pd.set_option("display.max_columns", 500)
display(dataset.head())
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d92
# 2  52cdef7c4bab8bd675297d8c
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d93
#
#                                          acquisition  \
# 0                                               None
# 1  {u'acquired_month': 5, u'price_amount': 200000...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []                None
# 2                                                 []
# 3                                                 []                None
# 4  [{u'acquired_month': 5, u'price_amount': 20000...                None
#
# ...

# %% [markdown]
# Después de haber visualizado los datos, he decidido que aquellos requisitos que voy a priorizar son:
#     1- Encontrarse cerca de empresas que tengan un valor superior a 1 millon de dólares;
#     2- Encontrarse cerca de empresas que tengan menos de 10 años de antigüedad (creadas al menos desde 2009)
#     3- Encontrarse cerca de lugares que tengan vida nocturna.

# %%
perfect_place = db.companies.find({"$and":
                                   [{"offices.latitude":{"$exists":True}},
                                    {"offices.latitude":{"$ne":None}},
                                    {"offices.longitude":{"$exists":True}},
                                    {"offices.longitude":{"$ne":None}},
                                    {"total_money_raised":{"$exists":True}},
                                    {"total_money_raised":{"$not":{"$size":0}}},
                                    {"founded_year":{"$gte":2000}},
                                    {"founded_year":{"$ne":None}},
                                    {"offices":{"$not":{"$size":0}}}]},
                                  {"name":1, "total_money_raised":1, "founded_year":1, "offices":1, 
                                   "offices.latitude": 1, "offices.longitude": 1, "_id":0})

# %%
from pandas.io.json import json_normalize


dataframe = json_normalize(data = perfect_place, record_path = "offices", 
                             meta = ["name", "founded_year",
                                    "total_money_raised"])

# %%
display(dataframe.head())
print(dataframe.shape)
print(dataframe.columns)
# Out:
#                           address1    address2        city country_code  \
# 0                  4900 Hopyard Rd   Suite 310  Pleasanton          USA
# 1                             None        None  Menlo Park          USA
# 2                 710 - 2nd Avenue  Suite 1100     Seattle          USA
# 3             270 Lafayette Street   Suite 505    New York          USA
# 4  16935 W. Bernardo Dr. Suite 101               San Diego          USA
#
#     description   latitude   longitude state_code zip_code total_money_raised  \
# 0  Headquarters  37.692934 -121.904945         CA    94588                 $0
# 1          None  37.484130 -122.169472         CA     None             $18.1M
# 2                47.603122 -122.333253         WA    98104             $39.8M
# 3                40.723731  -73.996431         NY    10012             $39.8M
# 4                33.022176 -117.081406         CA    92127             $73.1M
#
#        name  founded_year
# 0      Zoho          2005
# ...

# %%
df_aux = dataframe[["name", "latitude", "longitude", "founded_year", "city", "country_code", "total_money_raised"]]

# %%
df_aux.head()
# Out:
#        name   latitude   longitude  founded_year        city country_code  \
# 0      Zoho  37.692934 -121.904945          2005  Pleasanton          USA
# 1    Gizmoz  37.484130 -122.169472          2003  Menlo Park          USA
# 2  Wetpaint  47.603122 -122.333253          2005     Seattle          USA
# 3  Wetpaint  40.723731  -73.996431          2005    New York          USA
# 4   Slacker  33.022176 -117.081406          2006   San Diego          USA
#
#   total_money_raised
# 0                 $0
# 1             $18.1M
# 2             $39.8M
# 3             $39.8M
# 4             $73.1M

# %% [markdown]
# Ahora voy a limpiar los datos de cada una de las columnas que vamos a utilizar.

# %%
df_aux["total_offices"] = df_aux["name"].map(df_aux["name"].value_counts())
# Out:
# /home/marta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_offices_locat2(lon, lat):
    offices_locat = {
            "type":"Point",
            "coordinates":[lon, lat]
        }
    return offices_locat

# %%
df_aux["geo"] = df_aux.apply(lambda x: get_offices_locat2(x['longitude'], x['latitude']), axis=1)
# Out:
# /home/marta/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
display(df_aux.head())
print(df_aux.shape)
# Out:
#        name   latitude   longitude  founded_year        city country_code  \
# 0      Zoho  37.692934 -121.904945          2005  Pleasanton          USA
# 1    Gizmoz  37.484130 -122.169472          2003  Menlo Park          USA
# 2  Wetpaint  47.603122 -122.333253          2005     Seattle          USA
# 3  Wetpaint  40.723731  -73.996431          2005    New York          USA
# 4   Slacker  33.022176 -117.081406          2006   San Diego          USA
#
#   total_money_raised  total_offices  \
# 0                 $0              1
# 1             $18.1M              1
# 2             $39.8M              2
# 3             $39.8M              2
# 4             $73.1M              1
#
#                                                  geo
# 0  {u'type': u'Point', u'coordinates': [-121.9049...
# 1  {u'type': u'Point', u'coordinates': [-122.1694...
# 2  {u'type': u'Point', u'coordinates': [-122.3332...
# 3  {u'type': u'Point', u'coordinates': [-73.99643...
# ...

# %%
df_aux = df_aux.fillna(value=0)
df_aux.head()
# Out:
#        name   latitude   longitude  founded_year        city country_code  \
# 0      Zoho  37.692934 -121.904945          2005  Pleasanton          USA
# 1    Gizmoz  37.484130 -122.169472          2003  Menlo Park          USA
# 2  Wetpaint  47.603122 -122.333253          2005     Seattle          USA
# 3  Wetpaint  40.723731  -73.996431          2005    New York          USA
# 4   Slacker  33.022176 -117.081406          2006   San Diego          USA
#
#   total_money_raised  total_offices  \
# 0                 $0              1
# 1             $18.1M              1
# 2             $39.8M              2
# 3             $39.8M              2
# 4             $73.1M              1
#
#                                                  geo
# 0  {u'type': u'Point', u'coordinates': [-121.9049...
# 1  {u'type': u'Point', u'coordinates': [-122.1694...
# 2  {u'type': u'Point', u'coordinates': [-122.3332...
# 3  {u'type': u'Point', u'coordinates': [-73.99643...
# ...

# %%
#crear nueva columna con lista de lng, lat

# %%
df_aux["long-lat"]=df_aux["longitude"].astype(str) + ", " + df_aux["latitude"].astype(str)
df_aux
# Out:
#                          name   latitude   longitude  founded_year  \
# 0                        Zoho  37.692934 -121.904945          2005
# 1                      Gizmoz  37.484130 -122.169472          2003
# 2                    Wetpaint  47.603122 -122.333253          2005
# 3                    Wetpaint  40.723731  -73.996431          2005
# 4                     Slacker  33.022176 -117.081406          2006
# 5                      Scribd  37.789634 -122.404052          2007
# 6                       Helio  34.057498 -118.446596          2005
# 7                        Geni  34.090368 -118.393064          2006
# 8                     MeetMoi  40.757929  -73.985506          2007
# 9                    Babelgum  53.344104   -6.267494          2007
# 10                      Joost  40.746497  -74.009447          2006
# 11                       Digg  37.764726 -122.394523          2004
# 12                      Plaxo  37.387845 -122.055197          2002
# ...

# %%
df_aux.to_json('better_offices.json', orient="records")
