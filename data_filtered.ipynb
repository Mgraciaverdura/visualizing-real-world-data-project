# %% [markdown]
# # Filtrado de base de datos companies.json

# %% [markdown]
# Importo las librerías.

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
db = client["companies"]

from pandas.io.json import json_normalize

import pandas as pd

# %%
data = db.companies.find()
dataset = pd.DataFrame(list(data))
pd.set_option("display.max_columns", 500)
display(dataset.head())
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d92
# 2  52cdef7c4bab8bd675297d8c
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d93
#
#                                          acquisition  \
# 0                                               None
# 1  {'price_amount': 20000000, 'price_currency_cod...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                         acquisitions          alias_list  \
# 0                                                 []  Zoho ManageEngine
# 1                                                 []                None
# 2                                                 []
# 3                                                 []                None
# 4  [{'price_amount': 20000000, 'price_currency_co...                None
#
#                                        blog_feed_url  \
# 0
# 1  http://www.flektor-blog.com/video_editing_soft...
# 2                         http://blogs.zoho.com/feed
# 3              http://feeds.feedburner.com/omnidrive
# 4
#
#                         blog_url    category_code  \
# 0                                      enterprise
# 1    http://www.flektor-blog.com      games_video
# 2         http://blogs.zoho.com/         software
# 3  http://www.omnidrive.com/blog  network_hosting
# 4                                             web
#
#                                         competitions  \
# 0                                                 []
# 1  [{'competitor': {'name': 'RockYou', 'permalink...
# 2  [{'competitor': {'name': 'Empressr', 'permalin...
# 3  [{'competitor': {'name': 'Dropbox', 'permalink...
# 4                                                 []
#
#                      created_at  \
# 0           2007-05-25 19:24:22
# 1  Thu May 31 21:11:51 UTC 2007
# 2  Fri May 25 19:30:28 UTC 2007
# 3  Sun May 27 03:25:32 UTC 2007
# 4  Thu May 31 21:46:57 UTC 2007
#
#                                       crunchbase_url  deadpooled_day  \
# 0        http://www.crunchbase.com/company/adventnet             NaN
# 1          http://www.crunchbase.com/company/flektor             NaN
# 2             http://www.crunchbase.com/company/zoho             NaN
# 3        http://www.crunchbase.com/company/omnidrive            15.0
# 4  http://www.crunchbase.com/company/fox-interact...             NaN
#
#    deadpooled_month deadpooled_url  deadpooled_year  \
# 0               NaN            NaN              2.0
# 1               NaN           None              NaN
# 2               NaN            NaN              3.0
# 3               9.0                          2008.0
# 4               NaN                             NaN
#
#                   description       email_address  \
# 0  Server Management Software    pr@adventnet.com
# 1                        None                None
# 2  Online Business Apps Suite   info@zohocorp.com
# 3                        None  info@omnidrive.com
# 4
#
#                                       external_links  founded_day  \
# 0                                                 []          NaN
# 1                                                 []          NaN
# 2  [{'external_url': 'http://www.online-tech-tips...         15.0
# 3                                                 []          1.0
# 4                                                 []          1.0
#
#    founded_month  founded_year  \
# 0            NaN        1996.0
# 1            NaN           NaN
# 2            9.0        2005.0
# 3           11.0        2005.0
# 4            6.0        1979.0
#
#                                       funding_rounds  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'id': 225, 'round_code': 'angel', 'source_ur...
# 4                                                 []
#
#                homepage_url  \
# 0      http://adventnet.com
# 1    http://www.flektor.com
# 2           http://zoho.com
# 3  http://www.omnidrive.com
# 4   http://www.newscorp.com
#
#                                                image  \
# 0  {'available_sizes': [[[150, 55], 'assets/image...
# 1  {'available_sizes': [[[150, 68], 'assets/image...
# 2  {'available_sizes': [[[150, 55], 'assets/image...
# 3  {'available_sizes': [[[150, 85], 'assets/image...
# 4  {'available_sizes': [[[150, 71], 'assets/image...
#
#                                          investments   ipo  \
# 0                                                 []   NaN
# 1                                                 []  None
# 2                                                 []   NaN
# 3                                                 []  None
# 4  [{'funding_round': {'round_code': 'b', 'source...  None
#
#                                           milestones                   name  \
# 0                                                 []              AdventNet
# 1                                                 []                Flektor
# 2  [{'id': 388, 'description': 'Zoho Reaches 2 Mi...                   Zoho
# 3                                                 []              Omnidrive
# 4                                                 []  Fox Interactive Media
#
#    number_of_employees                                            offices  \
# 0                600.0  [{'description': 'Headquarters', 'address1': '...
# 1                  NaN  [{'description': None, 'address1': '8536 Natio...
# 2               1600.0  [{'description': 'Headquarters', 'address1': '...
# 3                  NaN  [{'description': '', 'address1': 'Suite 200', ...
# 4                  0.0  [{'description': '', 'address1': '407 N Maple ...
#
#                                             overview partners  \
# 0  <p>AdventNet is now <a href="/company/zoho-man...       []
# 1  <p>Flektor is a rich-media mash-up platform th...       []
# 2  <p>Zoho offers a suite of Business, Collaborat...       []
# 3  <p>Currently in public beta, Omnidrive makes i...       []
# 4  <p>Fox Interactive Media (FIM) oversees <a hre...       []
#
#                permalink    phone_number  \
# 0                   abc3    925-924-9500
# 1                flektor            None
# 2                   abc4  1-888-204-3539
# 3              omnidrive    660-675-5052
# 4  fox-interactive-media
#
#                                             products  \
# 0                                                 []
# 1      [{'name': 'Flektor', 'permalink': 'flektor'}]
# 2  [{'name': 'Zoho Office Suite', 'permalink': 'z...
# 3  [{'name': 'Omnidrive', 'permalink': 'omnidrive'}]
# 4                                                 []
#
#                                        providerships  \
# 0  [{'title': 'DHFH', 'is_past': True, 'provider'...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        relationships  \
# 0  [{'is_past': True, 'title': 'CEO and Co-Founde...
# 1  [{'is_past': True, 'title': 'COO, Co-Founder',...
# 2  [{'is_past': False, 'title': 'CEO and Founder'...
# 3  [{'is_past': True, 'title': 'Co-founder', 'per...
# 4  [{'is_past': False, 'title': '', 'person': {'f...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1                              flektor, photo, video                 $0
# 2  zoho, officesuite, spreadsheet, writer, projec...                 $0
# 3                     storage, sharing, edit, online              $800k
# 4                                                                    $0
#
#   twitter_username                    updated_at  \
# 0     manageengine  Wed Oct 31 18:26:09 UTC 2012
# 1             None  Sat Nov 05 08:42:23 UTC 2011
# 2             zoho  Wed Oct 30 00:07:05 UTC 2013
# 3         Nomadesk  Tue Jul 02 22:48:04 UTC 2013
# 4       twitterapi  Mon Aug 19 17:13:27 UTC 2013
#
#                                         video_embeds
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="430" height="2...
# 3                                                 []
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...

# %% [markdown]
# Después de haber visualizado los datos, he decidido que aquellos requisitos que voy a priorizar son:
#     1- Encontrarse cerca de empresas que tengan un valor superior a 1 millon de dólares;
#     2- Encontrarse cerca de empresas que tengan menos de 10 años de antigüedad (creadas al menos desde 2009)
#     3- Encontrarse cerca de lugares que tengan vida nocturna.

# %%
perfect_place = db.companies.find({"$and":[{"offices.latitude":{"$exists":True}},{"offices.latitude":{"$ne":None}},{"offices.longitude":{"$exists":True}},{"offices.longitude":{"$ne":None}},{"total_money_raised":{"$gte":"$1000000"}},{"total_money_raised":{"$ne":None}},{"founded_year":{"$gte":2009}},{"founded_year":{"$ne":None}},{"offices":{"$not":{"$size":0}}}]},{"name":1, "total_money_raised":1, "founded_year":1, "offices":1, "offices.latitude": 1, "offices.longitude": 1, "_id":0})

# %%
df = pd.DataFrame(perfect_place)
df.head()
# Out:
#    founded_year        name  \
# 0          2010       GENWI
# 1          2013       Fixya
# 2          2010     Needium
# 3          2012   Widgetbox
# 4          2011  RazorGator
#
#                                              offices total_money_raised
# 0    [{'latitude': 33.8171, 'longitude': -111.9035}]              $7.1M
# 1  [{'latitude': 37.566879, 'longitude': -122.323...                $8M
# 2  [{'latitude': 45.5049305, 'longitude': -73.568...                $1M
# 3  [{'latitude': 37.798853, 'longitude': -122.398...             $14.5M
# 4  [{'latitude': 34.047312, 'longitude': -118.445...             $58.8M

# %% [markdown]
# Ahora voy a limpiar los datos de cada una de las columnas que vamos a utilizar.

# %%
def getFirst(data):
    data = data['offices']
#    return (len(data),data[0]['latitude'],data[0]['longitude'])

    # Only create the geoJSON object if all geodata is available
    principal = None
    if data[0]['latitude'] and data[0]['longitude']:
        principal = {
            "type":"Point",
            "coordinates":[data[0]['longitude'], data[0]['latitude']]
        }

    return {
        "total_offices": len(data),
        "lat": data[0]['latitude'],
        "lng": data[0]['longitude'],
        "main_office": principal
    }


first_office = df[["offices"]].apply(getFirst, result_type="expand", axis=1)

# %%
df_clean = pd.concat([df,first_office], axis=1)[["name","lat","lng", "main_office","total_offices","total_money_raised","founded_year"]]

# %%
df_clean.head()
# Out:
#          name        lat         lng  \
# 0       GENWI  33.817100 -111.903500
# 1       Fixya  37.566879 -122.323895
# 2     Needium  45.504931  -73.568163
# 3   Widgetbox  37.798853 -122.398599
# 4  RazorGator  34.047312 -118.445243
#
#                                          main_office  total_offices  \
# 0  {'type': 'Point', 'coordinates': [-111.9035, 3...              1
# 1  {'type': 'Point', 'coordinates': [-122.323895,...              1
# 2  {'type': 'Point', 'coordinates': [-73.5681635,...              1
# 3  {'type': 'Point', 'coordinates': [-122.398599,...              1
# 4  {'type': 'Point', 'coordinates': [-118.445243,...              1
#
#   total_money_raised  founded_year
# 0              $7.1M          2010
# 1                $8M          2013
# 2                $1M          2010
# 3             $14.5M          2012
# 4             $58.8M          2011

# %%
df_clean.shape
# Out:
# (92, 7)

# %%
df_clean.to_json('oficinas.json', orient="records")

# %%
#pd.DataFrame(df_clean).to_csv("oficinas.csv")
